# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
#Data for Bravais Lattice Classification
Bravais_data=torch.load("Data/BravaisLattice_Data.pt")
#Data for Space Group Classification
Space_group=torch.load("Data/SpaceGroup_Data.pt")

# %%
bl_x=Bravais_data['X']
bl_y=Bravais_data['Y']

sg_x=Space_group['X']
sg_y=Space_group['Y']

# %%
xrange=np.arange(3, 155.1, 0.05)
plt.plot(xrange, bl_x[0].numpy())
plt.xlabel("2\u03B8")
plt.ylabel("Normalized Intensity")
plt.title("2\u03B8 vs Normalized Intensity");

# %%
xrange=np.arange(3, 155.05, 0.05)
plt.plot(xrange, sg_x[0].numpy())
plt.xlabel("2\u03B8")
plt.ylabel("Normalized Intensity")
plt.title("2\u03B8 vs Normalized Intensity");
